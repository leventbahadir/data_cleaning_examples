# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ri = pd.read_csv("police.csv") # I read the csv file for the police records
# Out:
# /Users/levent/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ri.head() # a quick look to the dataframe we have
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
ri.shape # the column and row numbers
# Out:
# (509681, 26)

# %%
ri.isnull().any() # we see the columns where there are missing values through isnull function
# Out:
# id                       False
# state                    False
# stop_date                 True
# stop_time                 True
# location_raw             False
# county_name               True
# county_fips               True
# fine_grained_location     True
# police_department         True
# driver_gender             True
# driver_age_raw            True
# driver_age                True
# driver_race_raw           True
# driver_race               True
# violation_raw             True
# violation                 True
# search_conducted          True
# search_type_raw           True
# search_type               True
# contraband_found         False
# stop_outcome              True
# is_arrested               True
# stop_duration             True
# out_of_state              True
# drugs_related_stop       False
# district                 False
# dtype: bool

# %%
ri.isnull().values.sum() # there are 2835154 null values in the dataframe which is a lot. It seems like some columns only have missing values
# Out:
# 2835154

# %%
ri['county_name'].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 509676    True
# 509677    True
# 509678    True
# 509679    True
# 509680    True
# Name: county_name, Length: 509681, dtype: bool

# %%
ri['county_name'].isnull().any()
# Out:
# True

# %%
# we see that in every value of county name, the values are missing

# %%
ri['county_fips'].isnull().any()
# Out:
# True

# %%
# same for county fips

# %%
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
# ri.drop("county_fips", axis = 1, inplace = True) I implemented this code to delete them, however, because I tried two times it gives an error, but we can see that from dataframe that it is already deleted

# %%
ri["state"].is_monotonic # we will delete this column too because the values are monotonic. everything is RI
# Out:
# True

# %%
ri["search_type_raw"].isnull().any() & ri["search_type"].isnull().any() # we see that these colums are empty too
# Out:
# True

# %%
ri.drop("search_type", axis = 1, inplace = True)
ri.drop("search_type_raw", axis = 1, inplace = True)

# %%
ri["fine_grained_location"].isnull().any()
# Out:
# True

# %%
ri.drop("fine_grained_location", axis = 1, inplace = True) # seems like we deleted most of the unnecessary rows

# %%
ri.head() # we can see that we got rid of the NaN columns and now we have 21 columns, we used to have 26
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips police_department driver_gender  driver_age_raw  ...  \
# 0          NaN               600             M          1985.0  ...
# 1          NaN               500             M          1987.0  ...
# 2          NaN                 0           NaN             NaN  ...
# 3          NaN               500             M          1986.0  ...
# 4          NaN               500             M          1978.0  ...
#
#                     violation_raw  violation search_conducted  \
# 0                        Speeding   Speeding            False
# ...

# %%
for i in ri.columns:
    if ri[i].isna().values.sum() > 500000:
        ri.drop(i, axis = 1, inplace = True) # I wrote this for function to check if we are good with the NaN values

# %%
ri.head() # yes, we are good
# Out:
#               id state   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4               500
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1                 0
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4               500
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw  ...  \
# 0             M          1985.0        20.0               W  ...
# 1             M          1987.0        18.0               W  ...
# 2           NaN             NaN         NaN             NaN  ...
# 3             M          1986.0        19.0               W  ...
# 4             M          1978.0        27.0               B  ...
#
#                     violation_raw  violation search_conducted  \
# ...

# %%
ri["driver_gender"].isna().values.sum() # these are the rows that are NaN under driver_gender column
# Out:
# 29097

# %%
ri["is_arrested"].head()
# Out:
# 0    False
# 1    False
# 2      NaN
# 3    False
# 4    False
# Name: is_arrested, dtype: object

# %%
type(ri["is_arrested"].dtypes)
# Out:
# numpy.dtype[object_]

# %%
ri["is_arrested"] = ri["is_arrested"].astype("bool")

# %%
type(ri["is_arrested"].dtypes) # I changed the data type to bool
# Out:
# numpy.dtype[bool_]

# %%
ri["is_arrested"] # now we can see better that when someone is arrested it gives True and the opposite for someone who is not
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 509676     True
# 509677     True
# 509678     True
# 509679     True
# 509680     True
# Name: is_arrested, Length: 509681, dtype: bool

# %%
# now I am going to concat the stop date and stop time and store them in a new column called 'stop'

# %%
ri["stop"] = ri["stop_date"] + " " + ri["stop_time"]

# %%
ri.head() # we can see the new column at the end
# Out:
#               id state   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4               500
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1                 0
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4               500
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw  ...  violation  \
# 0             M          1985.0        20.0               W  ...   Speeding
# 1             M          1987.0        18.0               W  ...   Speeding
# 2           NaN             NaN         NaN             NaN  ...        NaN
# 3             M          1986.0        19.0               W  ...  Equipment
# 4             M          1978.0        27.0               B  ...  Equipment
#
# ...

# %%
#ri.drop(["stop_time","stop_date"],axis=1,inplace=True)# since i combined them, these are unnecessary so i dropped them

# %%
cols = list(ri.columns.values) # I wanted to change the column order and get the new column stop from end to the front

# %%
cols
# Out:
# ['id',
#  'state',
#  'stop_date',
#  'stop_time',
#  'location_raw',
#  'police_department',
#  'driver_gender',
#  'driver_age_raw',
#  'driver_age',
#  'driver_race_raw',
#  'driver_race',
#  'violation_raw',
#  'violation',
#  'search_conducted',
#  'contraband_found',
#  'stop_outcome',
#  'is_arrested',
#  'stop_duration',
#  'out_of_state',
#  'drugs_related_stop',
#  'district',
#  'stop']

# %%
ri = ri[['id',
 'stop' ,
 'state',
 'location_raw',
 'police_department',
 'driver_gender',
 'driver_age_raw',
 'driver_age',
 'driver_race_raw', # i got it from the bottom of the list to the top and now I have it as the 3rd column
 'driver_race',
 'violation_raw',
 'violation',
 'search_conducted',
 'contraband_found',
 'stop_outcome',
 'is_arrested',
 'stop_duration',
 'out_of_state',
 'drugs_related_stop',
 'district']]

# %%
ri.head()
# Out:
#               id              stop state location_raw police_department  \
# 0  RI-2005-00001  2005-01-02 01:55    RI      Zone K1               600
# 1  RI-2005-00002  2005-01-02 20:30    RI      Zone X4               500
# 2  RI-2005-00003  2005-01-04 11:30    RI      Zone X1                 0
# 3  RI-2005-00004  2005-01-04 12:55    RI      Zone X4               500
# 4  RI-2005-00005  2005-01-06 01:30    RI      Zone X4               500
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  \
# 0             M          1985.0        20.0               W       White
# 1             M          1987.0        18.0               W       White
# 2           NaN             NaN         NaN             NaN         NaN
# 3             M          1986.0        19.0               W       White
# 4             M          1978.0        27.0               B       Black
#
#                     violation_raw  violation search_conducted  \
# ...

# %%
ri.shape
# Out:
# (509681, 20)

# %%
# now we have a cleaner data frame 
# it is ready for data analysis and visualization
